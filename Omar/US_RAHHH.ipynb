# %%
# Out:
# coefficient of determination: 0.671660953996172

# %%
# Out:
# coefficient of determination for the transforamtion: 0.8173798839832583

# %%
# Out:
# coefficient of determination: 0.7534417171132328
# Estimated probability: 0.0
